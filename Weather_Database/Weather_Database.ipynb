# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#create a set of 200 random latitudes and longitudes 
lats = np.random.uniform(low=-90.00, high=90.00, size=2000)
lngs = np.random.uniform(low=-180.00, high=180.00, size=2000)
lats_lngs = zip(lats,lngs)
lats_lngs

# %%
#add lats and lngs to a list
coordinates = list(lats_lngs)

# %%
from citipy import citipy

# %%
cities=[]
#identify the nearest city 
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
#append unique cities     
    if city not in cities:
        cities.append(city)
cities
# Out:
# ['port-cartier',
#  'krasnoselkup',
#  'uvalde',
#  'arcata',
#  'saint-leu',
#  'grand river south east',
#  'hambantota',
#  'ribeira grande',
#  'east london',
#  'thompson',
#  'albany',
#  'belushya guba',
#  'talcahuano',
#  'yar-sale',
#  'castro',
#  'dera din panah',
#  'beckley',
#  'gunnedah',
#  'aklera',
#  'sorland',
#  'mangochi',
#  'luanda',
#  'liepaja',
#  'busselton',
#  'buala',
#  'pevek',
#  'khatanga',
#  'kodiak',
#  'tuktoyaktuk',
#  'ushuaia',
#  'rikitea',
#  'punta arenas',
#  'puerto madryn',
#  'salinopolis',
#  'arraial do cabo',
#  'victor rosales',
#  'nikel',
#  'ciamis',
#  'oksfjord',
#  'cape town',
#  'vaini',
#  'jamestown',
#  'ahipara',
#  'sabang',
#  'illapel',
#  'kapaa',
#  'shimoda',
#  'illoqqortoormiut',
#  'zhanaozen',
#  'kruisfontein',
#  'nikolskoye',
#  'inuvik',
#  'pangnirtung',
#  'nanortalik',
#  'bilibino',
#  'los llanos de aridane',
#  'dikson',
#  'hithadhoo',
#  'ripoll',
#  'kavieng',
#  'teguise',
#  'mar del plata',
#  'faya',
#  'hobart',
#  'ponta do sol',
#  'port alfred',
#  'airai',
#  'cockburn town',
#  'alofi',
#  'hirara',
#  'fuyang',
#  'severo-kurilsk',
#  'avarua',
#  'hilo',
#  'dir',
#  'saldanha',
#  'attawapiskat',
#  'kamalasai',
#  'bluff',
#  'zyryanka',
#  'moche',
#  'shingu',
#  'bredasdorp',
#  'amderma',
#  'bud',
#  'do gonbadan',
#  'lolua',
#  'qarqin',
#  'cabo san lucas',
#  'mataura',
#  'chulman',
#  'richards bay',
#  'cabedelo',
#  'martaban',
#  'georgetown',
#  'padang',
#  'pacific grove',
#  'hami',
#  'new norfolk',
#  'carnarvon',
#  'ponta delgada',
#  'puerto ayora',
#  'tiarei',
#  'ancud',
#  'yafran',
#  'kozhva',
#  'torbay',
#  'codrington',
#  'atuona',
#  'hermanus',
#  'faanui',
#  'teavaro',
#  'hovd',
#  'kalmunai',
#  'meulaboh',
#  'buchanan',
#  'la mana',
#  'aklavik',
#  'gao',
#  'clarence town',
#  'koumac',
#  'barentsburg',
#  'pisco',
#  'butaritari',
#  'xining',
#  'mangrol',
#  'kijang',
#  'leningradskiy',
#  'chokurdakh',
#  'kolokani',
#  'siyabuswa',
#  'san quintin',
#  'norman wells',
#  'luderitz',
#  'goderich',
#  'vostok',
#  'belyy yar',
#  'hasaki',
#  'katsuura',
#  'quatre cocos',
#  'ambulu',
#  'leh',
#  'the pas',
#  'suluktu',
#  'ostrovnoy',
#  'rio gallegos',
#  'nhulunbuy',
#  'vardo',
#  'saint-philippe',
#  'pangody',
#  'lucapa',
#  'blackwater',
#  'atambua',
#  'berlevag',
#  'mmabatho',
#  'bambous virieux',
#  'oga',
#  'klaksvik',
#  'iqaluit',
#  'conceicao do araguaia',
#  'loveland',
#  'manokwari',
#  'cannes',
#  'ilulissat',
#  'svetlopolyansk',
#  'provideniya',
#  'charters towers',
#  'gniezno',
#  'erenhot',
#  'mackay',
#  'yuci',
#  'acapulco',
#  'inta',
#  'santiago de cuba',
#  'margate',
#  'slave lake',
#  'banda aceh',
#  'lorengau',
#  'mayor pablo lagerenza',
#  'elat',
#  'toftir',
#  'bambanglipuro',
#  'kovur',
#  'vila franca do campo',
#  'tura',
#  'skhisma',
#  'antalaha',
#  'divnomorskoye',
#  'pasighat',
#  'itarema',
#  'lompoc',
#  'burns lake',
#  'kawana waters',
#  'hobyo',
#  'pangai',
#  'bambari',
#  'ichhawar',
#  'sao filipe',
#  'victoria',
#  'chumikan',
#  'esperance',
#  'lagoa',
#  'yurga',
#  'portomaggiore',
#  'lata',
#  'fortuna',
#  'gilbues',
#  'saskylakh',
#  'north battleford',
#  'novaya igirma',
#  'barrow',
#  'udachnyy',
#  'srednekolymsk',
#  'esso',
#  'karasjok',
#  'alamosa',
#  'praia',
#  'tsihombe',
#  'la ronge',
#  'fairbanks',
#  'longyearbyen',
#  'mandalgovi',
#  'san pedro',
#  'caravelas',
#  'trinidad',
#  'galesong',
#  'sentyabrskiy',
#  'saleaula',
#  'harnosand',
#  'tondano',
#  'nha trang',
#  'ileza',
#  'upernavik',
#  'mahadday weyne',
#  'lebu',
#  'anloga',
#  'samusu',
#  'ayan',
#  'balabagan',
#  'talnakh',
#  'honiara',
#  'taolanaro',
#  'ust-nera',
#  'marcona',
#  'port blair',
#  'pierre',
#  'kavaratti',
#  'pokanayevka',
#  'cotonou',
#  'ananas',
#  'limbang',
#  'ngaoundere',
#  'taburi',
#  'olafsvik',
#  'sikasso',
#  'raudeberg',
#  'namie',
#  'acandi',
#  'great yarmouth',
#  'banepa',
#  'mata grande',
#  'santa cruz',
#  'san patricio',
#  'hofn',
#  'taoudenni',
#  'gardan diwal',
#  'tiksi',
#  'manzhouli',
#  'astakos',
#  'hamadan',
#  'isangel',
#  'wawa',
#  'puerto escondido',
#  'marshall',
#  'blythe',
#  'kaitangata',
#  'mao',
#  'yellowknife',
#  'chuy',
#  'zharkent',
#  'tevaitoa',
#  'bagli',
#  'port elizabeth',
#  'yulara',
#  'durant',
#  'solnechnyy',
#  'doha',
#  'sao joao da barra',
#  'kourou',
#  'san cristobal',
#  'gurgan',
#  'laguna',
#  'constitucion',
#  'qaanaaq',
#  'bugo',
#  'vuktyl',
#  'touros',
#  'half moon bay',
#  'vila velha',
#  'bandarban',
#  'labuhan',
#  'norrkoping',
#  'pitimbu',
#  'lavrentiya',
#  'deputatskiy',
#  'sitrah',
#  'lasa',
#  'lufilufi',
#  'tumannyy',
#  'haines junction',
#  'consett',
#  'te anau',
#  'muskogee',
#  'hamilton',
#  'vao',
#  'sataua',
#  'alice springs',
#  'portland',
#  'maltahohe',
#  'champerico',
#  'sug-aksy',
#  'bethel',
#  'aguimes',
#  'mys shmidta',
#  'jawhar',
#  'lusambo',
#  'strezhevoy',
#  'shelburne',
#  'saint george',
#  'mlonggo',
#  'biharamulo',
#  'mustasaari',
#  'emerald',
#  'santa vitoria do palmar',
#  'saint-pierre',
#  'najran',
#  'poum',
#  'strai',
#  'antofagasta',
#  'tazmalt',
#  'tuatapere',
#  'bathsheba',
#  'muisne',
#  'souillac',
#  'staraya toropa',
#  'president roxas',
#  'majalaya',
#  'farafangana',
#  'cherskiy',
#  'dingle',
#  'sorong',
#  'hermiston',
#  'cidreira',
#  'mnogovershinnyy',
#  'yialos',
#  'aban',
#  'yeletskiy',
#  'balaipungut',
#  'tabiauea',
#  'beringovskiy',
#  'sitka',
#  'palabuhanratu',
#  'tasiilaq',
#  'urengoy',
#  'mawlaik',
#  'saint-augustin',
#  'turkmenabat',
#  'luena',
#  'waipawa',
#  'black river',
#  'waingapu',
#  'williston',
#  'uruacu',
#  'kenora',
#  'baracoa',
#  'les cayes',
#  'lafiagi',
#  'marrakesh',
#  'jega',
#  'saint-joseph',
#  'makasar',
#  'mabua',
#  'merrill',
#  'komsomolskiy',
#  'lianzhou',
#  'sept-iles',
#  'asau',
#  'glasgow',
#  'berberati',
#  'we',
#  'bengkulu',
#  'khani',
#  'marawi',
#  'dahod',
#  'varhaug',
#  'lago da pedra',
#  'bhag',
#  'draguignan',
#  'sarkand',
#  'toora-khem',
#  'namatanai',
#  'aflu',
#  'marsh harbour',
#  'kuche',
#  'marsa matruh',
#  'lingao',
#  'sungaipenuh',
#  'avera',
#  'salalah',
#  'praya',
#  'anaimalai',
#  'fredericksburg',
#  'moba',
#  'northam',
#  'kachikau',
#  'guerrero negro',
#  'cayenne',
#  'el tocuyo',
#  'port hedland',
#  'spassk-ryazanskiy',
#  'gamba',
#  'okhotsk',
#  'whitehorse',
#  'bubaque',
#  'mier',
#  'zhangjiakou',
#  'ippy',
#  'howell',
#  'songea',
#  'tucurui',
#  'ambilobe',
#  'port lincoln',
#  'ruthin',
#  'jaisalmer',
#  'mitsamiouli',
#  'kathu',
#  'moron',
#  'nantucket',
#  'broken hill',
#  'camacha',
#  'santa rosalia',
#  'coquimbo',
#  'malartic',
#  'conde',
#  'yerbogachen',
#  'north platte',
#  'bougouni',
#  'muravlenko',
#  'kawalu',
#  'dzhusaly',
#  'tairua',
#  'chapais',
#  'mayo',
#  'cordoba',
#  'zeya',
#  'klenovyy',
#  'voi',
#  'pauini',
#  'omsukchan',
#  'buraydah',
#  'kimbe',
#  'verkhoyansk',
#  'volkhovskiy',
#  'moletai',
#  'visby',
#  'takoradi',
#  'dingzhou',
#  'pestyaki',
#  'anadyr',
#  'arawa',
#  'villamontes',
#  'bandar-e anzali',
#  'russas',
#  'maldonado',
#  'tucuma',
#  'kushima',
#  'halalo',
#  'geraldton',
#  'honningsvag',
#  'nago',
#  'trairi',
#  'havre-saint-pierre',
#  'tual',
#  'ketchikan',
#  'kirakira',
#  'amahai',
#  'brae',
#  'lalibela',
#  'sompeta',
#  'liwale',
#  'jiddah',
#  'serabu',
#  'wulanhaote',
#  'grand forks',
#  'prado',
#  'taraz',
#  'mount gambier',
#  'salinas',
#  'alugan',
#  'gimli',
#  'fort nelson',
#  'douentza',
#  'pingliang',
#  'rawson',
#  'muroto',
#  'batagay-alyta',
#  'road town',
#  'linxia',
#  'freeport',
#  'port hardy',
#  'northeim',
#  'san isidro',
#  'lixourion',
#  'drexel heights',
#  'pietersburg',
#  'maniitsoq',
#  'rembang',
#  'nome',
#  'gorom-gorom',
#  'ust-kamchatsk',
#  'bahia blanca',
#  'stod',
#  'chicama',
#  'palauig',
#  'arteaga',
#  'olavarria',
#  'haarby',
#  'altay',
#  'fort myers beach',
#  'samarai',
#  'tilichiki',
#  'narsaq',
#  'suzun',
#  'yantal',
#  'yuryevets',
#  'perelyub',
#  'carmarthen',
#  'fukue',
#  'nemuro',
#  'qala',
#  'pedernales',
#  'warkworth',
#  'skjervoy',
#  'burgeo',
#  'wiarton',
#  'flinders',
#  'am timan',
#  'smederevska palanka',
#  'teguldet',
#  'oranjemund',
#  'iquitos',
#  'rocky mountain house',
#  'saint-louis',
#  'kongolo',
#  'petauke',
#  'burghausen',
#  'hauknes',
#  'teya',
#  'sao miguel do araguaia',
#  'college',
#  'malumfashi',
#  'irbeyskoye',
#  'havelock',
#  'ciudad bolivar',
#  'eureka',
#  'rovinj',
#  'nishihara',
#  'benghazi',
#  'cairns',
#  'skalistyy',
#  'waiouru',
#  'kot isa khan',
#  'ariquemes',
#  'manakara',
#  'dijkot',
#  'asosa',
#  'korla',
#  'biltine',
#  'alyangula',
#  'kachiry',
#  'coxim',
#  'celestun',
#  'omaruru',
#  'praia da vitoria',
#  'vaasa',
#  'mentok',
#  'ixtapa',
#  'mananjary',
#  'bonavista',
#  'maunabo',
#  'huron',
#  'vitim',
#  'erdaojiang',
#  'san jeronimo',
#  'quang ngai',
#  'newport',
#  'matara',
#  'vavoua',
#  'ronne',
#  'nizhneyansk',
#  'manga',
#  'jalu',
#  'kaseda',
#  'kovdor',
#  'rayong',
#  'taltal',
#  'richmond',
#  'pasni',
#  'bati',
#  'kamenka',
#  'ostroleka',
#  'dongning',
#  'kalininskaya',
#  'iskateley',
#  'ridgecrest',
#  'zhangye',
#  'bocaiuva',
#  'acarau',
#  'bata',
#  'port augusta',
#  'kotelnich',
#  'samana',
#  'annau',
#  'surt',
#  'autun',
#  'morro bay',
#  'burica',
#  'kaman',
#  'montepuez',
#  'mount isa',
#  'ye',
#  'nabire',
#  'aykhal',
#  'manavalakurichi',
#  'natal',
#  'mayumba',
#  'tucumcari',
#  'malbork',
#  'yining',
#  'grand gaube',
#  'berbera',
#  'ovar',
#  'san juan',
#  'somers point',
#  'tabou',
#  'solenzo',
#  'atar',
#  'vestmannaeyjar',
#  'menongue',
#  'fairfield',
#  'changzhou',
#  'den helder',
#  'bowen',
#  'zaterechnyy',
#  'quelimane',
#  'sambava',
#  'mezhova',
#  'kholtoson',
#  'loa janan',
#  'leshukonskoye',
#  'qasigiannguit',
#  'kiama',
#  'tsienyane',
#  'lamu',
#  'kokstad',
#  'harper',
#  'inirida',
#  'kahului',
#  'goundam',
#  'abalak',
#  'yantzaza',
#  'umzimvubu',
#  'belmonte',
#  'viedma',
#  'lodja',
#  'pemangkat',
#  'cam ranh',
#  'phoenix',
#  'nalut',
#  'polunochnoye',
#  'inongo',
#  'ulladulla',
#  'rocha',
#  'shanghai',
#  'eirunepe',
#  'mahebourg',
#  'darnah',
#  'shahreza',
#  'sangin',
#  'verkhnyaya sysert',
#  'lazaro cardenas',
#  'kangaatsiaq',
#  'pudozh',
#  'lyubech',
#  'xingyi',
#  'bannu',
#  'clonakilty',
#  'sidhi',
#  'dawlatabad',
#  'uaua',
#  'abu dhabi',
#  'abu zabad',
#  'grindavik',
#  'mujiayingzi',
#  'stamsund',
#  'floro',
#  'alanya',
#  'pyu',
#  'chalus',
#  'mogadishu',
#  'groton',
#  'warqla',
#  'ruwi',
#  'vizinga',
#  'casas grandes',
#  'yamada',
#  'gorontalo',
#  'turtas',
#  'san policarpo',
#  'halden',
#  'tamboril',
#  'union city',
#  'biak',
#  'dwarka',
#  'lexington park',
#  'dhidhdhoo',
#  'cockburn harbour',
#  'kazalinsk',
#  'beloha',
#  'sao felix do xingu',
#  'taldan',
#  'kushmurun',
#  'verkhnyaya inta',
#  'otradnoye',
#  'nara',
#  'shuya',
#  'alta floresta',
#  'tupancireta',
#  'ranong',
#  'tatarsk',
#  'kraluv dvur',
#  'linjiang',
#  'karratha',
#  'byron bay',
#  'matagami',
#  'mont-dore',
#  'jiazi',
#  'kalianget',
#  'gasa',
#  'petropavlovsk-kamchatskiy',
#  'hit',
#  'tiznit',
#  'ust-tsilma',
#  'gambo',
#  'evensk']

# %%
#import the requests library
import requests

#import API Key
from config import weather_api_key

# %%
base_url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+ weather_api_key 
base_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=960223c3125812ad143bd8039296ff97'

# %%
# Create an empty list for weather data
city_data = []

#print logging 
print("Beginning Data Retrieval  ")
print("--------------------------")

# Create counters
record_count = 1
set_count = 1

#Proceed to loop through the cities in the list 
for i, city in enumerate(cities):
    
    #group cities i sets of 50 
    if (i % 50 == 0 and i >= 50):
        set_count +=1
        record_count = 0
    #create an endpoint URL for each city
    city_url = base_url + "&q=" + city
    
    #log the URL,record, and set numbers with city
    print (f"Processing Record {record_count} of set {set_count} | {city}")
    #then add 1 to the record count
    record_count += 1 
    
#run an API Request for all cities 
    try: 
        #parse JSON and get the required data
        city_weather = requests.get(city_url).json()
        
        
        #parse required data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        #append the city data into a list 
        city_data.append({"City":city.title(),
                                  "Lat": city_lat,
                                  "Lng": city_lng,
                                  "Max Temp":city_max_temp,
                                  "Humidity": city_humidity,
                                  "Cloudiness": city_clouds,
                                  "Wind Speed": city_wind,
                                  "Country": city_country,
                                  "Current Description": city_description})
#if an error occurs - skip city
    except:
        print("City not found. Skipping...")
        pass
    
#indicate complete data loading
print("-----------------------")
print("Data Retrieval Complete")
print("-----------------------")
# Out:
# Beginning Data Retrieval
# --------------------------
# Processing Record 1 of set 1 | port-cartier
# Processing Record 2 of set 1 | krasnoselkup
# Processing Record 3 of set 1 | uvalde
# Processing Record 4 of set 1 | arcata
# Processing Record 5 of set 1 | saint-leu
# Processing Record 6 of set 1 | grand river south east
# City not found. Skipping...
# Processing Record 7 of set 1 | hambantota
# Processing Record 8 of set 1 | ribeira grande
# Processing Record 9 of set 1 | east london
# Processing Record 10 of set 1 | thompson
# Processing Record 11 of set 1 | albany
# Processing Record 12 of set 1 | belushya guba
# City not found. Skipping...
# Processing Record 13 of set 1 | talcahuano
# Processing Record 14 of set 1 | yar-sale
# Processing Record 15 of set 1 | castro
# Processing Record 16 of set 1 | dera din panah
# City not found. Skipping...
# Processing Record 17 of set 1 | beckley
# Processing Record 18 of set 1 | gunnedah
# Processing Record 19 of set 1 | aklera
# Processing Record 20 of set 1 | sorland
# Processing Record 21 of set 1 | mangochi
# Processing Record 22 of set 1 | luanda
# Processing Record 23 of set 1 | liepaja
# Processing Record 24 of set 1 | busselton
# Processing Record 25 of set 1 | buala
# Processing Record 26 of set 1 | pevek
# Processing Record 27 of set 1 | khatanga
# Processing Record 28 of set 1 | kodiak
# Processing Record 29 of set 1 | tuktoyaktuk
# Processing Record 30 of set 1 | ushuaia
# Processing Record 31 of set 1 | rikitea
# Processing Record 32 of set 1 | punta arenas
# Processing Record 33 of set 1 | puerto madryn
# Processing Record 34 of set 1 | salinopolis
# Processing Record 35 of set 1 | arraial do cabo
# Processing Record 36 of set 1 | victor rosales
# Processing Record 37 of set 1 | nikel
# Processing Record 38 of set 1 | ciamis
# Processing Record 39 of set 1 | oksfjord
# Processing Record 40 of set 1 | cape town
# Processing Record 41 of set 1 | vaini
# Processing Record 42 of set 1 | jamestown
# Processing Record 43 of set 1 | ahipara
# Processing Record 44 of set 1 | sabang
# Processing Record 45 of set 1 | illapel
# Processing Record 46 of set 1 | kapaa
# Processing Record 47 of set 1 | shimoda
# Processing Record 48 of set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of set 1 | zhanaozen
# Processing Record 50 of set 1 | kruisfontein
# Processing Record 0 of set 2 | nikolskoye
# Processing Record 1 of set 2 | inuvik
# Processing Record 2 of set 2 | pangnirtung
# Processing Record 3 of set 2 | nanortalik
# Processing Record 4 of set 2 | bilibino
# Processing Record 5 of set 2 | los llanos de aridane
# Processing Record 6 of set 2 | dikson
# Processing Record 7 of set 2 | hithadhoo
# Processing Record 8 of set 2 | ripoll
# Processing Record 9 of set 2 | kavieng
# Processing Record 10 of set 2 | teguise
# Processing Record 11 of set 2 | mar del plata
# Processing Record 12 of set 2 | faya
# Processing Record 13 of set 2 | hobart
# Processing Record 14 of set 2 | ponta do sol
# Processing Record 15 of set 2 | port alfred
# Processing Record 16 of set 2 | airai
# Processing Record 17 of set 2 | cockburn town
# Processing Record 18 of set 2 | alofi
# Processing Record 19 of set 2 | hirara
# Processing Record 20 of set 2 | fuyang
# Processing Record 21 of set 2 | severo-kurilsk
# Processing Record 22 of set 2 | avarua
# Processing Record 23 of set 2 | hilo
# Processing Record 24 of set 2 | dir
# Processing Record 25 of set 2 | saldanha
# Processing Record 26 of set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of set 2 | kamalasai
# Processing Record 28 of set 2 | bluff
# Processing Record 29 of set 2 | zyryanka
# Processing Record 30 of set 2 | moche
# Processing Record 31 of set 2 | shingu
# Processing Record 32 of set 2 | bredasdorp
# Processing Record 33 of set 2 | amderma
# City not found. Skipping...
# Processing Record 34 of set 2 | bud
# Processing Record 35 of set 2 | do gonbadan
# Processing Record 36 of set 2 | lolua
# City not found. Skipping...
# Processing Record 37 of set 2 | qarqin
# Processing Record 38 of set 2 | cabo san lucas
# Processing Record 39 of set 2 | mataura
# Processing Record 40 of set 2 | chulman
# Processing Record 41 of set 2 | richards bay
# Processing Record 42 of set 2 | cabedelo
# Processing Record 43 of set 2 | martaban
# Processing Record 44 of set 2 | georgetown
# Processing Record 45 of set 2 | padang
# Processing Record 46 of set 2 | pacific grove
# Processing Record 47 of set 2 | hami
# Processing Record 48 of set 2 | new norfolk
# Processing Record 49 of set 2 | carnarvon
# Processing Record 0 of set 3 | ponta delgada
# Processing Record 1 of set 3 | puerto ayora
# Processing Record 2 of set 3 | tiarei
# Processing Record 3 of set 3 | ancud
# Processing Record 4 of set 3 | yafran
# Processing Record 5 of set 3 | kozhva
# Processing Record 6 of set 3 | torbay
# Processing Record 7 of set 3 | codrington
# Processing Record 8 of set 3 | atuona
# Processing Record 9 of set 3 | hermanus
# Processing Record 10 of set 3 | faanui
# Processing Record 11 of set 3 | teavaro
# Processing Record 12 of set 3 | hovd
# Processing Record 13 of set 3 | kalmunai
# Processing Record 14 of set 3 | meulaboh
# Processing Record 15 of set 3 | buchanan
# Processing Record 16 of set 3 | la mana
# Processing Record 17 of set 3 | aklavik
# Processing Record 18 of set 3 | gao
# Processing Record 19 of set 3 | clarence town
# Processing Record 20 of set 3 | koumac
# Processing Record 21 of set 3 | barentsburg
# City not found. Skipping...
# Processing Record 22 of set 3 | pisco
# Processing Record 23 of set 3 | butaritari
# Processing Record 24 of set 3 | xining
# Processing Record 25 of set 3 | mangrol
# Processing Record 26 of set 3 | kijang
# Processing Record 27 of set 3 | leningradskiy
# Processing Record 28 of set 3 | chokurdakh
# Processing Record 29 of set 3 | kolokani
# Processing Record 30 of set 3 | siyabuswa
# Processing Record 31 of set 3 | san quintin
# Processing Record 32 of set 3 | norman wells
# Processing Record 33 of set 3 | luderitz
# Processing Record 34 of set 3 | goderich
# Processing Record 35 of set 3 | vostok
# Processing Record 36 of set 3 | belyy yar
# Processing Record 37 of set 3 | hasaki
# Processing Record 38 of set 3 | katsuura
# Processing Record 39 of set 3 | quatre cocos
# Processing Record 40 of set 3 | ambulu
# Processing Record 41 of set 3 | leh
# Processing Record 42 of set 3 | the pas
# Processing Record 43 of set 3 | suluktu
# Processing Record 44 of set 3 | ostrovnoy
# Processing Record 45 of set 3 | rio gallegos
# Processing Record 46 of set 3 | nhulunbuy
# Processing Record 47 of set 3 | vardo
# Processing Record 48 of set 3 | saint-philippe
# Processing Record 49 of set 3 | pangody
# Processing Record 0 of set 4 | lucapa
# Processing Record 1 of set 4 | blackwater
# Processing Record 2 of set 4 | atambua
# Processing Record 3 of set 4 | berlevag
# Processing Record 4 of set 4 | mmabatho
# Processing Record 5 of set 4 | bambous virieux
# Processing Record 6 of set 4 | oga
# Processing Record 7 of set 4 | klaksvik
# Processing Record 8 of set 4 | iqaluit
# Processing Record 9 of set 4 | conceicao do araguaia
# Processing Record 10 of set 4 | loveland
# Processing Record 11 of set 4 | manokwari
# Processing Record 12 of set 4 | cannes
# Processing Record 13 of set 4 | ilulissat
# Processing Record 14 of set 4 | svetlopolyansk
# Processing Record 15 of set 4 | provideniya
# Processing Record 16 of set 4 | charters towers
# Processing Record 17 of set 4 | gniezno
# Processing Record 18 of set 4 | erenhot
# Processing Record 19 of set 4 | mackay
# Processing Record 20 of set 4 | yuci
# Processing Record 21 of set 4 | acapulco
# Processing Record 22 of set 4 | inta
# Processing Record 23 of set 4 | santiago de cuba
# Processing Record 24 of set 4 | margate
# Processing Record 25 of set 4 | slave lake
# Processing Record 26 of set 4 | banda aceh
# Processing Record 27 of set 4 | lorengau
# Processing Record 28 of set 4 | mayor pablo lagerenza
# Processing Record 29 of set 4 | elat
# Processing Record 30 of set 4 | toftir
# City not found. Skipping...
# Processing Record 31 of set 4 | bambanglipuro
# Processing Record 32 of set 4 | kovur
# Processing Record 33 of set 4 | vila franca do campo
# Processing Record 34 of set 4 | tura
# Processing Record 35 of set 4 | skhisma
# Processing Record 36 of set 4 | antalaha
# Processing Record 37 of set 4 | divnomorskoye
# Processing Record 38 of set 4 | pasighat
# Processing Record 39 of set 4 | itarema
# Processing Record 40 of set 4 | lompoc
# Processing Record 41 of set 4 | burns lake
# Processing Record 42 of set 4 | kawana waters
# City not found. Skipping...
# Processing Record 43 of set 4 | hobyo
# Processing Record 44 of set 4 | pangai
# Processing Record 45 of set 4 | bambari
# Processing Record 46 of set 4 | ichhawar
# Processing Record 47 of set 4 | sao filipe
# Processing Record 48 of set 4 | victoria
# Processing Record 49 of set 4 | chumikan
# Processing Record 0 of set 5 | esperance
# Processing Record 1 of set 5 | lagoa
# Processing Record 2 of set 5 | yurga
# Processing Record 3 of set 5 | portomaggiore
# Processing Record 4 of set 5 | lata
# Processing Record 5 of set 5 | fortuna
# Processing Record 6 of set 5 | gilbues
# Processing Record 7 of set 5 | saskylakh
# Processing Record 8 of set 5 | north battleford
# Processing Record 9 of set 5 | novaya igirma
# Processing Record 10 of set 5 | barrow
# Processing Record 11 of set 5 | udachnyy
# Processing Record 12 of set 5 | srednekolymsk
# Processing Record 13 of set 5 | esso
# Processing Record 14 of set 5 | karasjok
# Processing Record 15 of set 5 | alamosa
# Processing Record 16 of set 5 | praia
# Processing Record 17 of set 5 | tsihombe
# City not found. Skipping...
# Processing Record 18 of set 5 | la ronge
# Processing Record 19 of set 5 | fairbanks
# Processing Record 20 of set 5 | longyearbyen
# Processing Record 21 of set 5 | mandalgovi
# Processing Record 22 of set 5 | san pedro
# Processing Record 23 of set 5 | caravelas
# Processing Record 24 of set 5 | trinidad
# Processing Record 25 of set 5 | galesong
# Processing Record 26 of set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of set 5 | saleaula
# City not found. Skipping...
# Processing Record 28 of set 5 | harnosand
# Processing Record 29 of set 5 | tondano
# Processing Record 30 of set 5 | nha trang
# Processing Record 31 of set 5 | ileza
# Processing Record 32 of set 5 | upernavik
# Processing Record 33 of set 5 | mahadday weyne
# City not found. Skipping...
# Processing Record 34 of set 5 | lebu
# Processing Record 35 of set 5 | anloga
# Processing Record 36 of set 5 | samusu
# City not found. Skipping...
# Processing Record 37 of set 5 | ayan
# Processing Record 38 of set 5 | balabagan
# Processing Record 39 of set 5 | talnakh
# Processing Record 40 of set 5 | honiara
# Processing Record 41 of set 5 | taolanaro
# City not found. Skipping...
# Processing Record 42 of set 5 | ust-nera
# Processing Record 43 of set 5 | marcona
# City not found. Skipping...
# Processing Record 44 of set 5 | port blair
# Processing Record 45 of set 5 | pierre
# Processing Record 46 of set 5 | kavaratti
# Processing Record 47 of set 5 | pokanayevka
# City not found. Skipping...
# Processing Record 48 of set 5 | cotonou
# Processing Record 49 of set 5 | ananas
# Processing Record 0 of set 6 | limbang
# Processing Record 1 of set 6 | ngaoundere
# Processing Record 2 of set 6 | taburi
# City not found. Skipping...
# Processing Record 3 of set 6 | olafsvik
# Processing Record 4 of set 6 | sikasso
# Processing Record 5 of set 6 | raudeberg
# Processing Record 6 of set 6 | namie
# Processing Record 7 of set 6 | acandi
# Processing Record 8 of set 6 | great yarmouth
# Processing Record 9 of set 6 | banepa
# Processing Record 10 of set 6 | mata grande
# Processing Record 11 of set 6 | santa cruz
# Processing Record 12 of set 6 | san patricio
# Processing Record 13 of set 6 | hofn
# Processing Record 14 of set 6 | taoudenni
# Processing Record 15 of set 6 | gardan diwal
# City not found. Skipping...
# Processing Record 16 of set 6 | tiksi
# Processing Record 17 of set 6 | manzhouli
# Processing Record 18 of set 6 | astakos
# Processing Record 19 of set 6 | hamadan
# Processing Record 20 of set 6 | isangel
# Processing Record 21 of set 6 | wawa
# Processing Record 22 of set 6 | puerto escondido
# Processing Record 23 of set 6 | marshall
# Processing Record 24 of set 6 | blythe
# Processing Record 25 of set 6 | kaitangata
# Processing Record 26 of set 6 | mao
# Processing Record 27 of set 6 | yellowknife
# Processing Record 28 of set 6 | chuy
# Processing Record 29 of set 6 | zharkent
# Processing Record 30 of set 6 | tevaitoa
# Processing Record 31 of set 6 | bagli
# Processing Record 32 of set 6 | port elizabeth
# Processing Record 33 of set 6 | yulara
# Processing Record 34 of set 6 | durant
# Processing Record 35 of set 6 | solnechnyy
# Processing Record 36 of set 6 | doha
# Processing Record 37 of set 6 | sao joao da barra
# Processing Record 38 of set 6 | kourou
# Processing Record 39 of set 6 | san cristobal
# Processing Record 40 of set 6 | gurgan
# City not found. Skipping...
# Processing Record 41 of set 6 | laguna
# Processing Record 42 of set 6 | constitucion
# Processing Record 43 of set 6 | qaanaaq
# Processing Record 44 of set 6 | bugo
# Processing Record 45 of set 6 | vuktyl
# Processing Record 46 of set 6 | touros
# Processing Record 47 of set 6 | half moon bay
# Processing Record 48 of set 6 | vila velha
# Processing Record 49 of set 6 | bandarban
# Processing Record 0 of set 7 | labuhan
# Processing Record 1 of set 7 | norrkoping
# Processing Record 2 of set 7 | pitimbu
# Processing Record 3 of set 7 | lavrentiya
# Processing Record 4 of set 7 | deputatskiy
# Processing Record 5 of set 7 | sitrah
# Processing Record 6 of set 7 | lasa
# Processing Record 7 of set 7 | lufilufi
# Processing Record 8 of set 7 | tumannyy
# City not found. Skipping...
# Processing Record 9 of set 7 | haines junction
# Processing Record 10 of set 7 | consett
# Processing Record 11 of set 7 | te anau
# Processing Record 12 of set 7 | muskogee
# Processing Record 13 of set 7 | hamilton
# Processing Record 14 of set 7 | vao
# Processing Record 15 of set 7 | sataua
# City not found. Skipping...
# Processing Record 16 of set 7 | alice springs
# Processing Record 17 of set 7 | portland
# Processing Record 18 of set 7 | maltahohe
# Processing Record 19 of set 7 | champerico
# Processing Record 20 of set 7 | sug-aksy
# City not found. Skipping...
# Processing Record 21 of set 7 | bethel
# Processing Record 22 of set 7 | aguimes
# Processing Record 23 of set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of set 7 | jawhar
# Processing Record 25 of set 7 | lusambo
# Processing Record 26 of set 7 | strezhevoy
# Processing Record 27 of set 7 | shelburne
# Processing Record 28 of set 7 | saint george
# Processing Record 29 of set 7 | mlonggo
# Processing Record 30 of set 7 | biharamulo
# Processing Record 31 of set 7 | mustasaari
# Processing Record 32 of set 7 | emerald
# Processing Record 33 of set 7 | santa vitoria do palmar
# Processing Record 34 of set 7 | saint-pierre
# Processing Record 35 of set 7 | najran
# Processing Record 36 of set 7 | poum
# Processing Record 37 of set 7 | strai
# Processing Record 38 of set 7 | antofagasta
# Processing Record 39 of set 7 | tazmalt
# Processing Record 40 of set 7 | tuatapere
# Processing Record 41 of set 7 | bathsheba
# Processing Record 42 of set 7 | muisne
# Processing Record 43 of set 7 | souillac
# Processing Record 44 of set 7 | staraya toropa
# Processing Record 45 of set 7 | president roxas
# Processing Record 46 of set 7 | majalaya
# Processing Record 47 of set 7 | farafangana
# Processing Record 48 of set 7 | cherskiy
# Processing Record 49 of set 7 | dingle
# Processing Record 0 of set 8 | sorong
# Processing Record 1 of set 8 | hermiston
# Processing Record 2 of set 8 | cidreira
# Processing Record 3 of set 8 | mnogovershinnyy
# Processing Record 4 of set 8 | yialos
# City not found. Skipping...
# Processing Record 5 of set 8 | aban
# Processing Record 6 of set 8 | yeletskiy
# City not found. Skipping...
# Processing Record 7 of set 8 | balaipungut
# Processing Record 8 of set 8 | tabiauea
# City not found. Skipping...
# Processing Record 9 of set 8 | beringovskiy
# Processing Record 10 of set 8 | sitka
# Processing Record 11 of set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of set 8 | tasiilaq
# Processing Record 13 of set 8 | urengoy
# Processing Record 14 of set 8 | mawlaik
# Processing Record 15 of set 8 | saint-augustin
# Processing Record 16 of set 8 | turkmenabat
# Processing Record 17 of set 8 | luena
# Processing Record 18 of set 8 | waipawa
# Processing Record 19 of set 8 | black river
# Processing Record 20 of set 8 | waingapu
# Processing Record 21 of set 8 | williston
# Processing Record 22 of set 8 | uruacu
# Processing Record 23 of set 8 | kenora
# Processing Record 24 of set 8 | baracoa
# Processing Record 25 of set 8 | les cayes
# Processing Record 26 of set 8 | lafiagi
# Processing Record 27 of set 8 | marrakesh
# Processing Record 28 of set 8 | jega
# Processing Record 29 of set 8 | saint-joseph
# Processing Record 30 of set 8 | makasar
# Processing Record 31 of set 8 | mabua
# Processing Record 32 of set 8 | merrill
# Processing Record 33 of set 8 | komsomolskiy
# Processing Record 34 of set 8 | lianzhou
# Processing Record 35 of set 8 | sept-iles
# Processing Record 36 of set 8 | asau
# Processing Record 37 of set 8 | glasgow
# Processing Record 38 of set 8 | berberati
# Processing Record 39 of set 8 | we
# City not found. Skipping...
# Processing Record 40 of set 8 | bengkulu
# Processing Record 41 of set 8 | khani
# Processing Record 42 of set 8 | marawi
# Processing Record 43 of set 8 | dahod
# Processing Record 44 of set 8 | varhaug
# Processing Record 45 of set 8 | lago da pedra
# Processing Record 46 of set 8 | bhag
# Processing Record 47 of set 8 | draguignan
# Processing Record 48 of set 8 | sarkand
# Processing Record 49 of set 8 | toora-khem
# Processing Record 0 of set 9 | namatanai
# Processing Record 1 of set 9 | aflu
# City not found. Skipping...
# Processing Record 2 of set 9 | marsh harbour
# Processing Record 3 of set 9 | kuche
# City not found. Skipping...
# Processing Record 4 of set 9 | marsa matruh
# Processing Record 5 of set 9 | lingao
# Processing Record 6 of set 9 | sungaipenuh
# Processing Record 7 of set 9 | avera
# Processing Record 8 of set 9 | salalah
# Processing Record 9 of set 9 | praya
# Processing Record 10 of set 9 | anaimalai
# Processing Record 11 of set 9 | fredericksburg
# Processing Record 12 of set 9 | moba
# Processing Record 13 of set 9 | northam
# Processing Record 14 of set 9 | kachikau
# City not found. Skipping...
# Processing Record 15 of set 9 | guerrero negro
# Processing Record 16 of set 9 | cayenne
# Processing Record 17 of set 9 | el tocuyo
# Processing Record 18 of set 9 | port hedland
# Processing Record 19 of set 9 | spassk-ryazanskiy
# Processing Record 20 of set 9 | gamba
# Processing Record 21 of set 9 | okhotsk
# Processing Record 22 of set 9 | whitehorse
# Processing Record 23 of set 9 | bubaque
# Processing Record 24 of set 9 | mier
# Processing Record 25 of set 9 | zhangjiakou
# Processing Record 26 of set 9 | ippy
# Processing Record 27 of set 9 | howell
# Processing Record 28 of set 9 | songea
# Processing Record 29 of set 9 | tucurui
# Processing Record 30 of set 9 | ambilobe
# Processing Record 31 of set 9 | port lincoln
# Processing Record 32 of set 9 | ruthin
# Processing Record 33 of set 9 | jaisalmer
# Processing Record 34 of set 9 | mitsamiouli
# Processing Record 35 of set 9 | kathu
# Processing Record 36 of set 9 | moron
# Processing Record 37 of set 9 | nantucket
# Processing Record 38 of set 9 | broken hill
# Processing Record 39 of set 9 | camacha
# Processing Record 40 of set 9 | santa rosalia
# Processing Record 41 of set 9 | coquimbo
# Processing Record 42 of set 9 | malartic
# Processing Record 43 of set 9 | conde
# Processing Record 44 of set 9 | yerbogachen
# Processing Record 45 of set 9 | north platte
# Processing Record 46 of set 9 | bougouni
# Processing Record 47 of set 9 | muravlenko
# Processing Record 48 of set 9 | kawalu
# Processing Record 49 of set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 0 of set 10 | tairua
# Processing Record 1 of set 10 | chapais
# Processing Record 2 of set 10 | mayo
# Processing Record 3 of set 10 | cordoba
# Processing Record 4 of set 10 | zeya
# Processing Record 5 of set 10 | klenovyy
# Processing Record 6 of set 10 | voi
# Processing Record 7 of set 10 | pauini
# Processing Record 8 of set 10 | omsukchan
# Processing Record 9 of set 10 | buraydah
# Processing Record 10 of set 10 | kimbe
# Processing Record 11 of set 10 | verkhoyansk
# Processing Record 12 of set 10 | volkhovskiy
# Processing Record 13 of set 10 | moletai
# Processing Record 14 of set 10 | visby
# Processing Record 15 of set 10 | takoradi
# Processing Record 16 of set 10 | dingzhou
# Processing Record 17 of set 10 | pestyaki
# Processing Record 18 of set 10 | anadyr
# Processing Record 19 of set 10 | arawa
# Processing Record 20 of set 10 | villamontes
# Processing Record 21 of set 10 | bandar-e anzali
# Processing Record 22 of set 10 | russas
# Processing Record 23 of set 10 | maldonado
# Processing Record 24 of set 10 | tucuma
# Processing Record 25 of set 10 | kushima
# Processing Record 26 of set 10 | halalo
# City not found. Skipping...
# Processing Record 27 of set 10 | geraldton
# Processing Record 28 of set 10 | honningsvag
# Processing Record 29 of set 10 | nago
# Processing Record 30 of set 10 | trairi
# Processing Record 31 of set 10 | havre-saint-pierre
# Processing Record 32 of set 10 | tual
# Processing Record 33 of set 10 | ketchikan
# Processing Record 34 of set 10 | kirakira
# Processing Record 35 of set 10 | amahai
# Processing Record 36 of set 10 | brae
# Processing Record 37 of set 10 | lalibela
# Processing Record 38 of set 10 | sompeta
# Processing Record 39 of set 10 | liwale
# Processing Record 40 of set 10 | jiddah
# City not found. Skipping...
# Processing Record 41 of set 10 | serabu
# Processing Record 42 of set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 43 of set 10 | grand forks
# Processing Record 44 of set 10 | prado
# Processing Record 45 of set 10 | taraz
# Processing Record 46 of set 10 | mount gambier
# Processing Record 47 of set 10 | salinas
# Processing Record 48 of set 10 | alugan
# Processing Record 49 of set 10 | gimli
# Processing Record 0 of set 11 | fort nelson
# Processing Record 1 of set 11 | douentza
# Processing Record 2 of set 11 | pingliang
# Processing Record 3 of set 11 | rawson
# Processing Record 4 of set 11 | muroto
# Processing Record 5 of set 11 | batagay-alyta
# Processing Record 6 of set 11 | road town
# Processing Record 7 of set 11 | linxia
# Processing Record 8 of set 11 | freeport
# Processing Record 9 of set 11 | port hardy
# Processing Record 10 of set 11 | northeim
# Processing Record 11 of set 11 | san isidro
# Processing Record 12 of set 11 | lixourion
# Processing Record 13 of set 11 | drexel heights
# Processing Record 14 of set 11 | pietersburg
# Processing Record 15 of set 11 | maniitsoq
# Processing Record 16 of set 11 | rembang
# Processing Record 17 of set 11 | nome
# Processing Record 18 of set 11 | gorom-gorom
# Processing Record 19 of set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 20 of set 11 | bahia blanca
# Processing Record 21 of set 11 | stod
# Processing Record 22 of set 11 | chicama
# Processing Record 23 of set 11 | palauig
# Processing Record 24 of set 11 | arteaga
# Processing Record 25 of set 11 | olavarria
# Processing Record 26 of set 11 | haarby
# City not found. Skipping...
# Processing Record 27 of set 11 | altay
# Processing Record 28 of set 11 | fort myers beach
# Processing Record 29 of set 11 | samarai
# Processing Record 30 of set 11 | tilichiki
# Processing Record 31 of set 11 | narsaq
# Processing Record 32 of set 11 | suzun
# Processing Record 33 of set 11 | yantal
# Processing Record 34 of set 11 | yuryevets
# Processing Record 35 of set 11 | perelyub
# Processing Record 36 of set 11 | carmarthen
# Processing Record 37 of set 11 | fukue
# Processing Record 38 of set 11 | nemuro
# Processing Record 39 of set 11 | qala
# Processing Record 40 of set 11 | pedernales
# Processing Record 41 of set 11 | warkworth
# Processing Record 42 of set 11 | skjervoy
# Processing Record 43 of set 11 | burgeo
# Processing Record 44 of set 11 | wiarton
# Processing Record 45 of set 11 | flinders
# Processing Record 46 of set 11 | am timan
# Processing Record 47 of set 11 | smederevska palanka
# Processing Record 48 of set 11 | teguldet
# Processing Record 49 of set 11 | oranjemund
# Processing Record 0 of set 12 | iquitos
# Processing Record 1 of set 12 | rocky mountain house
# Processing Record 2 of set 12 | saint-louis
# Processing Record 3 of set 12 | kongolo
# Processing Record 4 of set 12 | petauke
# Processing Record 5 of set 12 | burghausen
# Processing Record 6 of set 12 | hauknes
# Processing Record 7 of set 12 | teya
# Processing Record 8 of set 12 | sao miguel do araguaia
# Processing Record 9 of set 12 | college
# Processing Record 10 of set 12 | malumfashi
# Processing Record 11 of set 12 | irbeyskoye
# Processing Record 12 of set 12 | havelock
# Processing Record 13 of set 12 | ciudad bolivar
# Processing Record 14 of set 12 | eureka
# Processing Record 15 of set 12 | rovinj
# Processing Record 16 of set 12 | nishihara
# Processing Record 17 of set 12 | benghazi
# Processing Record 18 of set 12 | cairns
# Processing Record 19 of set 12 | skalistyy
# City not found. Skipping...
# Processing Record 20 of set 12 | waiouru
# Processing Record 21 of set 12 | kot isa khan
# Processing Record 22 of set 12 | ariquemes
# Processing Record 23 of set 12 | manakara
# Processing Record 24 of set 12 | dijkot
# Processing Record 25 of set 12 | asosa
# Processing Record 26 of set 12 | korla
# Processing Record 27 of set 12 | biltine
# Processing Record 28 of set 12 | alyangula
# Processing Record 29 of set 12 | kachiry
# Processing Record 30 of set 12 | coxim
# Processing Record 31 of set 12 | celestun
# Processing Record 32 of set 12 | omaruru
# Processing Record 33 of set 12 | praia da vitoria
# Processing Record 34 of set 12 | vaasa
# Processing Record 35 of set 12 | mentok
# City not found. Skipping...
# Processing Record 36 of set 12 | ixtapa
# Processing Record 37 of set 12 | mananjary
# Processing Record 38 of set 12 | bonavista
# Processing Record 39 of set 12 | maunabo
# Processing Record 40 of set 12 | huron
# Processing Record 41 of set 12 | vitim
# Processing Record 42 of set 12 | erdaojiang
# Processing Record 43 of set 12 | san jeronimo
# Processing Record 44 of set 12 | quang ngai
# Processing Record 45 of set 12 | newport
# Processing Record 46 of set 12 | matara
# Processing Record 47 of set 12 | vavoua
# Processing Record 48 of set 12 | ronne
# Processing Record 49 of set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 0 of set 13 | manga
# Processing Record 1 of set 13 | jalu
# Processing Record 2 of set 13 | kaseda
# Processing Record 3 of set 13 | kovdor
# Processing Record 4 of set 13 | rayong
# Processing Record 5 of set 13 | taltal
# Processing Record 6 of set 13 | richmond
# Processing Record 7 of set 13 | pasni
# Processing Record 8 of set 13 | bati
# Processing Record 9 of set 13 | kamenka
# Processing Record 10 of set 13 | ostroleka
# Processing Record 11 of set 13 | dongning
# Processing Record 12 of set 13 | kalininskaya
# Processing Record 13 of set 13 | iskateley
# Processing Record 14 of set 13 | ridgecrest
# Processing Record 15 of set 13 | zhangye
# Processing Record 16 of set 13 | bocaiuva
# Processing Record 17 of set 13 | acarau
# Processing Record 18 of set 13 | bata
# Processing Record 19 of set 13 | port augusta
# Processing Record 20 of set 13 | kotelnich
# Processing Record 21 of set 13 | samana
# Processing Record 22 of set 13 | annau
# Processing Record 23 of set 13 | surt
# Processing Record 24 of set 13 | autun
# Processing Record 25 of set 13 | morro bay
# Processing Record 26 of set 13 | burica
# City not found. Skipping...
# Processing Record 27 of set 13 | kaman
# Processing Record 28 of set 13 | montepuez
# Processing Record 29 of set 13 | mount isa
# Processing Record 30 of set 13 | ye
# City not found. Skipping...
# Processing Record 31 of set 13 | nabire
# Processing Record 32 of set 13 | aykhal
# Processing Record 33 of set 13 | manavalakurichi
# Processing Record 34 of set 13 | natal
# Processing Record 35 of set 13 | mayumba
# Processing Record 36 of set 13 | tucumcari
# Processing Record 37 of set 13 | malbork
# Processing Record 38 of set 13 | yining
# Processing Record 39 of set 13 | grand gaube
# Processing Record 40 of set 13 | berbera
# Processing Record 41 of set 13 | ovar
# Processing Record 42 of set 13 | san juan
# Processing Record 43 of set 13 | somers point
# Processing Record 44 of set 13 | tabou
# Processing Record 45 of set 13 | solenzo
# Processing Record 46 of set 13 | atar
# Processing Record 47 of set 13 | vestmannaeyjar
# Processing Record 48 of set 13 | menongue
# Processing Record 49 of set 13 | fairfield
# Processing Record 0 of set 14 | changzhou
# Processing Record 1 of set 14 | den helder
# Processing Record 2 of set 14 | bowen
# Processing Record 3 of set 14 | zaterechnyy
# Processing Record 4 of set 14 | quelimane
# Processing Record 5 of set 14 | sambava
# Processing Record 6 of set 14 | mezhova
# Processing Record 7 of set 14 | kholtoson
# Processing Record 8 of set 14 | loa janan
# Processing Record 9 of set 14 | leshukonskoye
# Processing Record 10 of set 14 | qasigiannguit
# Processing Record 11 of set 14 | kiama
# Processing Record 12 of set 14 | tsienyane
# City not found. Skipping...
# Processing Record 13 of set 14 | lamu
# Processing Record 14 of set 14 | kokstad
# Processing Record 15 of set 14 | harper
# Processing Record 16 of set 14 | inirida
# Processing Record 17 of set 14 | kahului
# Processing Record 18 of set 14 | goundam
# Processing Record 19 of set 14 | abalak
# Processing Record 20 of set 14 | yantzaza
# Processing Record 21 of set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of set 14 | belmonte
# Processing Record 23 of set 14 | viedma
# Processing Record 24 of set 14 | lodja
# Processing Record 25 of set 14 | pemangkat
# Processing Record 26 of set 14 | cam ranh
# Processing Record 27 of set 14 | phoenix
# Processing Record 28 of set 14 | nalut
# Processing Record 29 of set 14 | polunochnoye
# Processing Record 30 of set 14 | inongo
# Processing Record 31 of set 14 | ulladulla
# Processing Record 32 of set 14 | rocha
# Processing Record 33 of set 14 | shanghai
# Processing Record 34 of set 14 | eirunepe
# Processing Record 35 of set 14 | mahebourg
# Processing Record 36 of set 14 | darnah
# Processing Record 37 of set 14 | shahreza
# Processing Record 38 of set 14 | sangin
# Processing Record 39 of set 14 | verkhnyaya sysert
# Processing Record 40 of set 14 | lazaro cardenas
# Processing Record 41 of set 14 | kangaatsiaq
# Processing Record 42 of set 14 | pudozh
# Processing Record 43 of set 14 | lyubech
# Processing Record 44 of set 14 | xingyi
# Processing Record 45 of set 14 | bannu
# Processing Record 46 of set 14 | clonakilty
# Processing Record 47 of set 14 | sidhi
# Processing Record 48 of set 14 | dawlatabad
# Processing Record 49 of set 14 | uaua
# Processing Record 0 of set 15 | abu dhabi
# Processing Record 1 of set 15 | abu zabad
# Processing Record 2 of set 15 | grindavik
# Processing Record 3 of set 15 | mujiayingzi
# Processing Record 4 of set 15 | stamsund
# City not found. Skipping...
# Processing Record 5 of set 15 | floro
# Processing Record 6 of set 15 | alanya
# Processing Record 7 of set 15 | pyu
# Processing Record 8 of set 15 | chalus
# Processing Record 9 of set 15 | mogadishu
# Processing Record 10 of set 15 | groton
# Processing Record 11 of set 15 | warqla
# City not found. Skipping...
# Processing Record 12 of set 15 | ruwi
# Processing Record 13 of set 15 | vizinga
# Processing Record 14 of set 15 | casas grandes
# Processing Record 15 of set 15 | yamada
# Processing Record 16 of set 15 | gorontalo
# Processing Record 17 of set 15 | turtas
# Processing Record 18 of set 15 | san policarpo
# Processing Record 19 of set 15 | halden
# Processing Record 20 of set 15 | tamboril
# Processing Record 21 of set 15 | union city
# Processing Record 22 of set 15 | biak
# Processing Record 23 of set 15 | dwarka
# Processing Record 24 of set 15 | lexington park
# Processing Record 25 of set 15 | dhidhdhoo
# Processing Record 26 of set 15 | cockburn harbour
# City not found. Skipping...
# Processing Record 27 of set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 28 of set 15 | beloha
# Processing Record 29 of set 15 | sao felix do xingu
# Processing Record 30 of set 15 | taldan
# Processing Record 31 of set 15 | kushmurun
# Processing Record 32 of set 15 | verkhnyaya inta
# Processing Record 33 of set 15 | otradnoye
# Processing Record 34 of set 15 | nara
# Processing Record 35 of set 15 | shuya
# Processing Record 36 of set 15 | alta floresta
# Processing Record 37 of set 15 | tupancireta
# Processing Record 38 of set 15 | ranong
# Processing Record 39 of set 15 | tatarsk
# Processing Record 40 of set 15 | kraluv dvur
# Processing Record 41 of set 15 | linjiang
# Processing Record 42 of set 15 | karratha
# Processing Record 43 of set 15 | byron bay
# Processing Record 44 of set 15 | matagami
# Processing Record 45 of set 15 | mont-dore
# Processing Record 46 of set 15 | jiazi
# Processing Record 47 of set 15 | kalianget
# Processing Record 48 of set 15 | gasa
# Processing Record 49 of set 15 | petropavlovsk-kamchatskiy
# Processing Record 0 of set 16 | hit
# Processing Record 1 of set 16 | tiznit
# Processing Record 2 of set 16 | ust-tsilma
# Processing Record 3 of set 16 | gambo
# Processing Record 4 of set 16 | evensk
# -----------------------
# Data Retrieval Complete
# -----------------------

# %%
#create a DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Port-Cartier  50.03  -66.87     55.99        47          40        6.93
# 1    Krasnoselkup  65.70   82.47     32.36        94         100       24.00
# 2          Uvalde  29.37  -99.77     81.00        61          40        6.93
# 3          Arcata  40.87 -124.08     53.60       100          90        2.89
# 4       Saint-Leu -21.15   55.28     73.40        83          75       13.87
# ..            ...    ...     ...       ...       ...         ...         ...
# 700           Hit  33.64   42.83     83.50        23           0        6.51
# 701        Tiznit  29.58   -9.50     68.92        63           0        9.95
# 702    Ust-Tsilma  65.44   52.15     35.82        84          91        2.93
# 703         Gambo   4.65   22.26     75.33        77          10        1.63
# 704        Evensk  61.95  159.23     35.67        79           0        4.00
#
#     Country Current Description
# 0        CA    scattered clouds
# 1        RU     overcast clouds
# 2        US    scattered clouds
# 3        US                 fog
# 4        RE       broken clouds
# ..      ...                 ...
# 700      IQ           clear sky
# 701      MA           clear sky
# 702      RU     overcast clouds
# 703      CF           clear sky
# 704      RU           clear sky
#
# [705 rows x 9 columns]

# %%
new_column_order=["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_complete_df=city_data_df[new_column_order]
city_data_complete_df
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0    Port-Cartier      CA  50.03  -66.87     55.99        47          40
# 1    Krasnoselkup      RU  65.70   82.47     32.36        94         100
# 2          Uvalde      US  29.37  -99.77     81.00        61          40
# 3          Arcata      US  40.87 -124.08     53.60       100          90
# 4       Saint-Leu      RE -21.15   55.28     73.40        83          75
# ..            ...     ...    ...     ...       ...       ...         ...
# 700           Hit      IQ  33.64   42.83     83.50        23           0
# 701        Tiznit      MA  29.58   -9.50     68.92        63           0
# 702    Ust-Tsilma      RU  65.44   52.15     35.82        84          91
# 703         Gambo      CF   4.65   22.26     75.33        77          10
# 704        Evensk      RU  61.95  159.23     35.67        79           0
#
#      Wind Speed Current Description
# 0          6.93    scattered clouds
# 1         24.00     overcast clouds
# 2          6.93    scattered clouds
# 3          2.89                 fog
# 4         13.87       broken clouds
# ..          ...                 ...
# 700        6.51           clear sky
# 701        9.95           clear sky
# 702        2.93     overcast clouds
# 703        1.63           clear sky
# 704        4.00           clear sky
#
# [705 rows x 9 columns]

# %%
#Export data as CSV
WeatherPy_Database = "Weather_Database"
city_data_complete_df.to_csv(WeatherPy_Database, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-e222e6642b8b> in <module>
#       1 #Export data as CSV
# ----> 2 city_data_complete_df.to_csv(WeatherPy_Database.csv, index_label="City_ID")
#
# AttributeError: 'str' object has no attribute 'csv'
